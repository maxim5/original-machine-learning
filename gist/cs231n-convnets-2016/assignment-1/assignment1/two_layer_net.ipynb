# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform classification, and test it out on the CIFAR-10 dataset.

# %%
# A bit of setup

import numpy as np
import matplotlib.pyplot as plt

from cs231n.classifiers.neural_net import TwoLayerNet

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %% [markdown]
# We will use the class `TwoLayerNet` in the file `cs231n/classifiers/neural_net.py` to represent instances of our network. The network parameters are stored in the instance variable `self.params` where keys are string parameter names and values are numpy arrays. Below, we initialize toy data and a toy model that we will use to develop your implementation.

# %%
# Create a small net and some toy data to check your implementations.
# Note that we set the random seed for repeatable experiments.

input_size = 4
hidden_size = 10
num_classes = 3
num_inputs = 5

def init_toy_model():
  np.random.seed(0)
  return TwoLayerNet(input_size, hidden_size, num_classes, std=1e-1)

def init_toy_data():
  np.random.seed(1)
  X = 10 * np.random.randn(num_inputs, input_size)
  y = np.array([0, 1, 2, 2, 1])
  return X, y

net = init_toy_model()
X, y = init_toy_data()

# %% [markdown]
# # Forward pass: compute scores
# Open the file `cs231n/classifiers/neural_net.py` and look at the method `TwoLayerNet.loss`. This function is very similar to the loss functions you have written for the SVM and Softmax exercises: It takes the data and weights and computes the class scores, the loss, and the gradients on the parameters.
#
# Implement the first part of the forward pass which uses the weights and biases to compute the scores for all inputs.

# %%
scores = net.loss(X)
print 'Your scores:'
print scores
print
print 'correct scores:'
correct_scores = np.asarray([
  [-0.81233741, -1.27654624, -0.70335995],
  [-0.17129677, -1.18803311, -0.47310444],
  [-0.51590475, -1.01354314, -0.8504215 ],
  [-0.15419291, -0.48629638, -0.52901952],
  [-0.00618733, -0.12435261, -0.15226949]])
print correct_scores
print

# The difference should be very small. We get < 1e-7
print 'Difference between your scores and correct scores:'
print np.sum(np.abs(scores - correct_scores))
# Out:
# Your scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# correct scores:
# [[-0.81233741 -1.27654624 -0.70335995]
#  [-0.17129677 -1.18803311 -0.47310444]
#  [-0.51590475 -1.01354314 -0.8504215 ]
#  [-0.15419291 -0.48629638 -0.52901952]
#  [-0.00618733 -0.12435261 -0.15226949]]
#
# Difference between your scores and correct scores:
# 3.68027209324e-08

# %% [markdown]
# # Forward pass: compute loss
# In the same function, implement the second part that computes the data and regularizaion loss.

# %%
loss, _ = net.loss(X, y, reg=0.1)
correct_loss = 1.30378789133

print loss
print correct_loss

# should be very small, we get < 1e-12
print 'Difference between your loss and correct loss:'
print np.sum(np.abs(loss - correct_loss))
# Out:
# 1.30378789133
# 1.30378789133
# Difference between your loss and correct loss:
# 1.79412040779e-13

# %% [markdown]
# # Backward pass
# Implement the rest of the function. This will compute the gradient of the loss with respect to the variables `W1`, `b1`, `W2`, and `b2`. Now that you (hopefully!) have a correctly implemented forward pass, you can debug your backward pass using a numeric gradient check:

# %%
from cs231n.gradient_check import eval_numerical_gradient

# Use numeric gradient checking to check your implementation of the backward pass.
# If your implementation is correct, the difference between the numeric and
# analytic gradients should be less than 1e-8 for each of W1, W2, b1, and b2.

loss, grads = net.loss(X, y, reg=0.1)

# these should all be less than 1e-8 or so
for param_name in grads:
  f = lambda W: net.loss(X, y, reg=0.1)[0]
  param_grad_num = eval_numerical_gradient(f, net.params[param_name], verbose=False)
  print '%s max relative error: %e' % (param_name, rel_error(param_grad_num, grads[param_name]))
# Out:
# b2 max relative error: 4.447677e-11
# W2 max relative error: 3.440708e-09
# W1 max relative error: 3.561318e-09
# b1 max relative error: 2.738421e-09

# %% [markdown]
# # Train the network
# To train the network we will use stochastic gradient descent (SGD), similar to the SVM and Softmax classifiers. Look at the function `TwoLayerNet.train` and fill in the missing sections to implement the training procedure. This should be very similar to the training procedure you used for the SVM and Softmax classifiers. You will also have to implement `TwoLayerNet.predict`, as the training process periodically performs prediction to keep track of accuracy over time while the network trains.
#
# Once you have implemented the method, run the code below to train a two-layer network on toy data. You should achieve a training loss less than 0.2.

# %%
net = init_toy_model()
stats = net.train(X, y, X, y,
                  learning_rate=1e-1, reg=1e-5,
                  num_iters=100, verbose=False)

print 'Final training loss: ', stats['loss_history'][-1]

# plot the loss history
plt.plot(stats['loss_history'])
plt.xlabel('iteration')
plt.ylabel('training loss')
plt.title('Training Loss history')
plt.show()
# Out:
# Final training loss:  0.0171496079387

# %% [markdown]
# # Load the data
# Now that you have implemented a two-layer network that passes gradient checks and works on toy data, it's time to load up our favorite CIFAR-10 data so we can use it to train a classifier on a real dataset.

# %%
from cs231n.data_utils import load_CIFAR10

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the two-layer neural net classifier. These are the same steps as
    we used for the SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
        
    # Subsample the data
    mask = range(num_training, num_training + num_validation)
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = range(num_training)
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = range(num_test)
    X_test = X_test[mask]
    y_test = y_test[mask]

    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis=0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image

    # Reshape data to rows
    X_train = X_train.reshape(num_training, -1)
    X_val = X_val.reshape(num_validation, -1)
    X_test = X_test.reshape(num_test, -1)

    return X_train, y_train, X_val, y_val, X_test, y_test


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
# Out:
# Train data shape:  (49000, 3072)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3072)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3072)
# Test labels shape:  (1000,)

# %% [markdown]
# # Train a network
# To train our network we will use SGD with momentum. In addition, we will adjust the learning rate with an exponential learning rate schedule as optimization proceeds; after each epoch, we will reduce the learning rate by multiplying it by a decay rate.

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10
net = TwoLayerNet(input_size, hidden_size, num_classes)

# Train the network
stats = net.train(X_train, y_train, X_val, y_val,
                  num_iters=2000, batch_size=200,
                  learning_rate=5e-4, learning_rate_decay=0.97,
                  reg=0.5, verbose=True)

# Predict on the validation set
val_acc = (net.predict(X_val) == y_val).mean()
print 'Validation accuracy: ', val_acc
# Out:
# iteration 0 / 2000: loss 2.302967
# iteration 100 / 2000: loss 2.147428
# iteration 200 / 2000: loss 1.876702
# iteration 300 / 2000: loss 1.829579
# iteration 400 / 2000: loss 1.736277
# iteration 500 / 2000: loss 1.827753
# iteration 600 / 2000: loss 1.683361
# iteration 700 / 2000: loss 1.647826
# iteration 800 / 2000: loss 1.650139
# iteration 900 / 2000: loss 1.627745
# iteration 1000 / 2000: loss 1.606112
# iteration 1100 / 2000: loss 1.563844
# iteration 1200 / 2000: loss 1.583121
# iteration 1300 / 2000: loss 1.613672
# iteration 1400 / 2000: loss 1.518950
# iteration 1500 / 2000: loss 1.542500
# iteration 1600 / 2000: loss 1.513942
# iteration 1700 / 2000: loss 1.507649
# iteration 1800 / 2000: loss 1.482497
# iteration 1900 / 2000: loss 1.346583
# Validation accuracy:  0.497

# %% [markdown]
# # Debug the training
# With the default parameters we provided above, you should get a validation accuracy of about 0.29 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(stats['loss_history'])
plt.title('Loss history')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(stats['train_acc_history'], label='train', color='red')
plt.plot(stats['val_acc_history'], label='val', color='green')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.show()

# %%
from cs231n.vis_utils import visualize_grid

# Visualize the weights of the network

def show_net_weights(net):
  W1 = net.params['W1']
  W1 = W1.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)
  plt.imshow(visualize_grid(W1, padding=3).astype('uint8'))
  plt.gca().axis('off')
  plt.show()

show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength. You might also consider tuning the learning rate decay, but you should be able to get good performance using the default value.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 48% on the validation set. Our best network gets over 52% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on CIFAR-10 as you can, with a fully-connected Neural Network. For every 1% above 52% on the Test set we will award you with one extra bonus point. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).

# %%
input_size = 32 * 32 * 3
hidden_size = 50
num_classes = 10

best_net = None # store the best model into this 
best_acc = 0

for epoch in xrange(100):
    num_iters = 2000
    batch_size = 200
    learning_rate = 10**np.random.uniform(-2.5, -4.0)
    learning_rate_decay = np.random.uniform(0.95, 0.99)
    reg = 10**np.random.uniform(-2, 1)
    
    net = TwoLayerNet(input_size, hidden_size, num_classes)

    # Train the network
    stats = net.train(X_train, y_train, X_val, y_val,
                      num_iters=num_iters, batch_size=batch_size,
                      learning_rate=learning_rate, learning_rate_decay=learning_rate_decay,
                      reg=reg, verbose=False)

    # Predict on the validation set
    val_acc = (net.predict(X_val) == y_val).mean()
    print 'Validation accuracy=%f. Hyper: num_iters=%d, batch_size=%d, lr=%f, lrd=%f, reg=%f' % \
          (val_acc, num_iters, batch_size, learning_rate, learning_rate_decay, reg)
    if best_acc < val_acc:
        best_acc = val_acc
        best_net = net
        print 'Best so far!'
# Out:
# Validation accuracy=0.469000. Hyper: num_iters=2000, batch_size=200, lr=0.000824, lrd=0.980763, reg=0.202621
# Best so far!
# Validation accuracy=0.380000. Hyper: num_iters=2000, batch_size=200, lr=0.000112, lrd=0.960477, reg=0.014959
# Validation accuracy=0.378000. Hyper: num_iters=2000, batch_size=200, lr=0.000118, lrd=0.968473, reg=0.227724
# Validation accuracy=0.474000. Hyper: num_iters=2000, batch_size=200, lr=0.000325, lrd=0.953677, reg=0.102961
# Best so far!
# Validation accuracy=0.446000. Hyper: num_iters=2000, batch_size=200, lr=0.000307, lrd=0.966831, reg=0.010248
# Validation accuracy=0.470000. Hyper: num_iters=2000, batch_size=200, lr=0.000333, lrd=0.966988, reg=0.053370
# Validation accuracy=0.448000. Hyper: num_iters=2000, batch_size=200, lr=0.000212, lrd=0.984267, reg=0.037606
# Validation accuracy=0.467000. Hyper: num_iters=2000, batch_size=200, lr=0.000304, lrd=0.982477, reg=0.063264
# Validation accuracy=0.481000. Hyper: num_iters=2000, batch_size=200, lr=0.000444, lrd=0.975761, reg=0.036955
# Best so far!
# Validation accuracy=0.490000. Hyper: num_iters=2000, batch_size=200, lr=0.000813, lrd=0.987024, reg=0.081607
# Best so far!
# Validation accuracy=0.489000. Hyper: num_iters=2000, batch_size=200, lr=0.000674, lrd=0.984042, reg=0.186421
# Validation accuracy=0.454000. Hyper: num_iters=2000, batch_size=200, lr=0.000262, lrd=0.961766, reg=0.057726
# Validation accuracy=0.399000. Hyper: num_iters=2000, batch_size=200, lr=0.000143, lrd=0.955619, reg=0.013319
# Validation accuracy=0.452000. Hyper: num_iters=2000, batch_size=200, lr=0.000242, lrd=0.955463, reg=0.531973
# Validation accuracy=0.470000. Hyper: num_iters=2000, batch_size=200, lr=0.000462, lrd=0.975764, reg=0.862786
# Validation accuracy=0.494000. Hyper: num_iters=2000, batch_size=200, lr=0.000789, lrd=0.976920, reg=0.099397
# Best so far!
# Validation accuracy=0.476000. Hyper: num_iters=2000, batch_size=200, lr=0.000440, lrd=0.974161, reg=0.121716
# Validation accuracy=0.477000. Hyper: num_iters=2000, batch_size=200, lr=0.000457, lrd=0.950079, reg=0.108221
# Validation accuracy=0.439000. Hyper: num_iters=2000, batch_size=200, lr=0.000184, lrd=0.983285, reg=0.010810
# Validation accuracy=0.432000. Hyper: num_iters=2000, batch_size=200, lr=0.000212, lrd=0.950427, reg=0.392198
# Validation accuracy=0.479000. Hyper: num_iters=2000, batch_size=200, lr=0.000262, lrd=0.982795, reg=0.015040
# Validation accuracy=0.481000. Hyper: num_iters=2000, batch_size=200, lr=0.000586, lrd=0.969206, reg=0.930718
# Validation accuracy=0.495000. Hyper: num_iters=2000, batch_size=200, lr=0.000967, lrd=0.980143, reg=0.287061
# Best so far!
# Validation accuracy=0.470000. Hyper: num_iters=2000, batch_size=200, lr=0.000344, lrd=0.965586, reg=0.109504
# Validation accuracy=0.459000. Hyper: num_iters=2000, batch_size=200, lr=0.000273, lrd=0.977960, reg=0.010787
# Validation accuracy=0.420000. Hyper: num_iters=2000, batch_size=200, lr=0.000149, lrd=0.968791, reg=0.020319
# Validation accuracy=0.512000. Hyper: num_iters=2000, batch_size=200, lr=0.000489, lrd=0.980858, reg=0.019634
# Best so far!
# Validation accuracy=0.413000. Hyper: num_iters=2000, batch_size=200, lr=0.000156, lrd=0.958448, reg=0.040606
# Validation accuracy=0.478000. Hyper: num_iters=2000, batch_size=200, lr=0.000473, lrd=0.986906, reg=0.011508
# Validation accuracy=0.411000. Hyper: num_iters=2000, batch_size=200, lr=0.000141, lrd=0.979637, reg=0.013032
# Validation accuracy=0.440000. Hyper: num_iters=2000, batch_size=200, lr=0.000197, lrd=0.979512, reg=0.062828
# Validation accuracy=0.464000. Hyper: num_iters=2000, batch_size=200, lr=0.000401, lrd=0.954200, reg=0.027186
# Validation accuracy=0.454000. Hyper: num_iters=2000, batch_size=200, lr=0.000246, lrd=0.956885, reg=0.373946
# Validation accuracy=0.499000. Hyper: num_iters=2000, batch_size=200, lr=0.000682, lrd=0.982932, reg=0.036688
# Validation accuracy=0.428000. Hyper: num_iters=2000, batch_size=200, lr=0.000171, lrd=0.988338, reg=0.368336
# Validation accuracy=0.492000. Hyper: num_iters=2000, batch_size=200, lr=0.000667, lrd=0.961694, reg=0.202885
# Validation accuracy=0.493000. Hyper: num_iters=2000, batch_size=200, lr=0.000483, lrd=0.953414, reg=0.014550
# Validation accuracy=0.462000. Hyper: num_iters=2000, batch_size=200, lr=0.000302, lrd=0.958250, reg=0.017135
# Validation accuracy=0.471000. Hyper: num_iters=2000, batch_size=200, lr=0.000581, lrd=0.980407, reg=0.092051
# Validation accuracy=0.462000. Hyper: num_iters=2000, batch_size=200, lr=0.000261, lrd=0.977205, reg=0.036026
# Validation accuracy=0.483000. Hyper: num_iters=2000, batch_size=200, lr=0.000987, lrd=0.978494, reg=0.073495
# Validation accuracy=0.466000. Hyper: num_iters=2000, batch_size=200, lr=0.000456, lrd=0.976411, reg=0.024942
# Validation accuracy=0.460000. Hyper: num_iters=2000, batch_size=200, lr=0.000232, lrd=0.986821, reg=0.015389
# Validation accuracy=0.477000. Hyper: num_iters=2000, batch_size=200, lr=0.000796, lrd=0.964413, reg=0.301553
# Validation accuracy=0.410000. Hyper: num_iters=2000, batch_size=200, lr=0.000170, lrd=0.955498, reg=0.052098
# Validation accuracy=0.496000. Hyper: num_iters=2000, batch_size=200, lr=0.000791, lrd=0.950680, reg=0.626334
# Validation accuracy=0.481000. Hyper: num_iters=2000, batch_size=200, lr=0.000566, lrd=0.971977, reg=0.663194
# Validation accuracy=0.467000. Hyper: num_iters=2000, batch_size=200, lr=0.000281, lrd=0.960209, reg=0.135978
# Validation accuracy=0.485000. Hyper: num_iters=2000, batch_size=200, lr=0.000535, lrd=0.986641, reg=0.049068
# Validation accuracy=0.475000. Hyper: num_iters=2000, batch_size=200, lr=0.000969, lrd=0.985635, reg=0.216695
# Validation accuracy=0.433000. Hyper: num_iters=2000, batch_size=200, lr=0.000175, lrd=0.962171, reg=0.097500
# Validation accuracy=0.476000. Hyper: num_iters=2000, batch_size=200, lr=0.000877, lrd=0.981980, reg=0.819794
# Validation accuracy=0.397000. Hyper: num_iters=2000, batch_size=200, lr=0.000125, lrd=0.971003, reg=0.020890
# Validation accuracy=0.479000. Hyper: num_iters=2000, batch_size=200, lr=0.000807, lrd=0.952925, reg=0.194001
# Validation accuracy=0.504000. Hyper: num_iters=2000, batch_size=200, lr=0.000998, lrd=0.986941, reg=0.033077
# Validation accuracy=0.394000. Hyper: num_iters=2000, batch_size=200, lr=0.000112, lrd=0.984581, reg=0.192665
# Validation accuracy=0.432000. Hyper: num_iters=2000, batch_size=200, lr=0.000175, lrd=0.976828, reg=0.012026
# Validation accuracy=0.392000. Hyper: num_iters=2000, batch_size=200, lr=0.000133, lrd=0.978101, reg=0.104816
# Validation accuracy=0.395000. Hyper: num_iters=2000, batch_size=200, lr=0.000136, lrd=0.957480, reg=0.067833
# Validation accuracy=0.475000. Hyper: num_iters=2000, batch_size=200, lr=0.000346, lrd=0.978232, reg=0.017584
# Validation accuracy=0.372000. Hyper: num_iters=2000, batch_size=200, lr=0.000104, lrd=0.951519, reg=0.014459
# Validation accuracy=0.367000. Hyper: num_iters=2000, batch_size=200, lr=0.000102, lrd=0.957464, reg=0.013848
# Validation accuracy=0.462000. Hyper: num_iters=2000, batch_size=200, lr=0.000293, lrd=0.959621, reg=0.016913
# Validation accuracy=0.491000. Hyper: num_iters=2000, batch_size=200, lr=0.000776, lrd=0.986735, reg=0.028571
# Validation accuracy=0.430000. Hyper: num_iters=2000, batch_size=200, lr=0.000192, lrd=0.965275, reg=0.019647
# Validation accuracy=0.493000. Hyper: num_iters=2000, batch_size=200, lr=0.000577, lrd=0.989246, reg=0.021455
# Validation accuracy=0.411000. Hyper: num_iters=2000, batch_size=200, lr=0.000154, lrd=0.969362, reg=0.015606
# Validation accuracy=0.484000. Hyper: num_iters=2000, batch_size=200, lr=0.000597, lrd=0.976794, reg=0.633900
# Validation accuracy=0.464000. Hyper: num_iters=2000, batch_size=200, lr=0.000308, lrd=0.954655, reg=0.504566
# Validation accuracy=0.385000. Hyper: num_iters=2000, batch_size=200, lr=0.000117, lrd=0.977572, reg=0.107803
# Validation accuracy=0.378000. Hyper: num_iters=2000, batch_size=200, lr=0.000113, lrd=0.964361, reg=0.032208
# Validation accuracy=0.479000. Hyper: num_iters=2000, batch_size=200, lr=0.000435, lrd=0.970736, reg=0.503994
# Validation accuracy=0.454000. Hyper: num_iters=2000, batch_size=200, lr=0.000287, lrd=0.953003, reg=0.126385
# Validation accuracy=0.381000. Hyper: num_iters=2000, batch_size=200, lr=0.000104, lrd=0.984814, reg=0.091562
# Validation accuracy=0.487000. Hyper: num_iters=2000, batch_size=200, lr=0.000747, lrd=0.978064, reg=0.083846
# Validation accuracy=0.431000. Hyper: num_iters=2000, batch_size=200, lr=0.000178, lrd=0.974588, reg=0.015195
# Validation accuracy=0.444000. Hyper: num_iters=2000, batch_size=200, lr=0.000234, lrd=0.973291, reg=0.419926
# Validation accuracy=0.476000. Hyper: num_iters=2000, batch_size=200, lr=0.000800, lrd=0.962663, reg=0.564138
# Validation accuracy=0.483000. Hyper: num_iters=2000, batch_size=200, lr=0.000637, lrd=0.963781, reg=0.619593
# Validation accuracy=0.470000. Hyper: num_iters=2000, batch_size=200, lr=0.000478, lrd=0.951990, reg=0.022943
# Validation accuracy=0.409000. Hyper: num_iters=2000, batch_size=200, lr=0.000130, lrd=0.987796, reg=0.094413
# Validation accuracy=0.464000. Hyper: num_iters=2000, batch_size=200, lr=0.000329, lrd=0.973534, reg=0.340564
# Validation accuracy=0.453000. Hyper: num_iters=2000, batch_size=200, lr=0.000256, lrd=0.966616, reg=0.845489
# Validation accuracy=0.386000. Hyper: num_iters=2000, batch_size=200, lr=0.000106, lrd=0.981621, reg=0.020796
# Validation accuracy=0.457000. Hyper: num_iters=2000, batch_size=200, lr=0.000288, lrd=0.958129, reg=0.144319
# Validation accuracy=0.472000. Hyper: num_iters=2000, batch_size=200, lr=0.000380, lrd=0.967338, reg=0.045475
# Validation accuracy=0.459000. Hyper: num_iters=2000, batch_size=200, lr=0.000329, lrd=0.963435, reg=0.480716
# Validation accuracy=0.398000. Hyper: num_iters=2000, batch_size=200, lr=0.000148, lrd=0.960747, reg=0.230246
# Validation accuracy=0.399000. Hyper: num_iters=2000, batch_size=200, lr=0.000126, lrd=0.974671, reg=0.034972
# Validation accuracy=0.461000. Hyper: num_iters=2000, batch_size=200, lr=0.000327, lrd=0.968566, reg=0.168062
# Validation accuracy=0.403000. Hyper: num_iters=2000, batch_size=200, lr=0.000128, lrd=0.980302, reg=0.010924
# Validation accuracy=0.371000. Hyper: num_iters=2000, batch_size=200, lr=0.000118, lrd=0.964921, reg=0.213203
# Validation accuracy=0.466000. Hyper: num_iters=2000, batch_size=200, lr=0.000322, lrd=0.987762, reg=0.089718
# Validation accuracy=0.476000. Hyper: num_iters=2000, batch_size=200, lr=0.000432, lrd=0.969233, reg=0.649301
# Validation accuracy=0.482000. Hyper: num_iters=2000, batch_size=200, lr=0.000681, lrd=0.986081, reg=0.165740
# Validation accuracy=0.497000. Hyper: num_iters=2000, batch_size=200, lr=0.000587, lrd=0.952407, reg=0.027604
# Validation accuracy=0.468000. Hyper: num_iters=2000, batch_size=200, lr=0.000398, lrd=0.956475, reg=0.482874
# Validation accuracy=0.464000. Hyper: num_iters=2000, batch_size=200, lr=0.000276, lrd=0.974177, reg=0.035758
# Validation accuracy=0.473000. Hyper: num_iters=2000, batch_size=200, lr=0.000782, lrd=0.988886, reg=0.714349
# Validation accuracy=0.511000. Hyper: num_iters=2000, batch_size=200, lr=0.000972, lrd=0.965005, reg=0.063654

# %%
# visualize the weights of the best network
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 48%.
#
# **We will give you extra bonus point for every 1% of accuracy above 52%.**

# %%
test_acc = (best_net.predict(X_test) == y_test).mean()
print 'Test accuracy: ', test_acc
# Out:
# Test accuracy:  0.487
